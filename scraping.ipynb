# %% [markdown]
# ## Web Scraping

# %%
import requests
from bs4 import BeautifulSoup

# %%
BASE_URL = "https://www.procyclingstats.com"
race = "tour-de-france"
year = "2020"
stage_no = 10

# %%
url_result = f"{BASE_URL}/race/{race}/{year}/stage-{stage_no}/result"
url_profile = f"{BASE_URL}/race/{race}/{year}/stage-{stage_no}/today/profiles"

# %%
# Parsing result
res = requests.get(url_profile)

# %%
soup = BeautifulSoup(res.text, "html.parser")

# %%
res.status_code
# Out:
# 200

# %%
# Start-finish & distance
tags = soup.select("h2 span.red")
start_finish = tags[0].text.split("\xa0")
start_finish = " ".join([x.strip() for x in start_finish if x])

distance = tags[1].text.strip("()k")

# %%
distance
# Out:
# '36.2'

# %%
# Time trial
"ITT" in soup.select("h2 span.blue")[0].text
# Out:
# True

# %%
# Winner
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html>
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-35889790-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-35889790-1');
#   </script>
#   <title>
#    Tour de France 2020 | Stage 20 (ITT) | Results
#   </title>
#   <base href="https://www.procyclingstats.com/race.php"/>
#   <meta charset="utf-8"/>
#   <meta content="" name="language">
#    <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#    <meta content="View full results of Stage 20 (ITT) in Tour de France 2020 from Lure to La Planche des Belles Filles over 36.2 kilometre. Won by Tadej Pogačar before Tom Dumoulin (2nd) and Richie Porte (3rd). " name="description"/>
#    <meta content=" " name="keywords"/>
# ...

# %%
soup.select("td > a[href]")[0]["href"].split("/")[-1]
# Out:
# 'tadej-pogacar'

# %%
body > div.wrapper > div.content > div.res-left > div:nth-child(3) > table > tbody > tr:nth-child(1) > td:nth-child(5)

# %%
print(soup.prettify())
# Out:
# "uppercase">
#    Politt
#   </span>
#   Nils
#  </a>
#  <span class="teammob">
#   Israel Start-Up Nation
#  </span>
# </td>
# <td class="hide" data-name="age">
#  26
# </td>
# <td class="cu600">
#  <a href="team/israel-start-up-nation-2020">
#   Israel Start-Up Nation
#  </a>
# </td>
# <td>
#  2
# </td>
# <td class="hide" data-name="pnts_today">
#  -
# </td>
# <tr data-id="1360" data-line="0" data-nation="be">
#  <td>
#   58
#  </td>
# </tr>
# <td>
#  <span style="font-size: 10px; color: #777; ">
#   57
#  </span>
# </td>
# <td>
#  <span style="color: #e00; font-size: 10px; ">
#   ▼1
#  </span>
# </td>
# <td class="hide" data-name="bib">
#  201
# </td>
# <td>
#  <span class="flag be">
#  </span>
#  <a href="rider/tiesj-benoot">
#   <span class="uppercase">
#    Benoot
#   </span>
#   Tiesj
#  </a>
#  <span class="teammob">
#   Team Sunweb
#  </span>
# </td>
# <td class="hide" data-name="age">
#  26
# </td>
# <td class="cu600">
#  <a href="team/team-sunweb-2020">
#   Team Sunweb
# ...

# %%
soup.find("tr")
# Out:
# <tr><th style="width: 40px; ">Rnk</th><th class="hide" data-name="gc" style="width: 50px; ">GC</th><th class="hide" data-name="gc" style="width: 70px; ">GC-Time</th><th class="hide" data-name="bib" style="width: 40px; ">BIB</th><th style="width: 250px; ">Rider</th><th class="hide" data-name="age" style="width: 50px; ">Age</th><th class="cu600" style="width: 250px; ">Team</th><th style="width: 50px; ">UCI</th><th style="width: 50px; ">Pnt</th><th style="width: 50px; ">Avg</th><th "="" style="width: 50px;  text-align: right; ">Time</th></tr>

# %%
url_result
# Out:
# 'https://www.procyclingstats.com/race/tour-de-france/2020/stage-20/result'

# %%
from src.procyclingstats import parse_stage

# %%
parse_stage(res)
# Out:
# {'start/finish': "île d'Oléron (Le Château-d'Oléron) › Île de Ré (Saint-Martin-de-Ré)",
#  'distance': 168.5,
#  'time trial': False,
#  'winner': 'sam-bennett'}

# %%
soup.select("div.statDivLeft img:first-of-type")[0]["src"]
# Out:
# 'images/profiles/ap/cb/tour-de-france-2020-stage-10-profile-6a06b6d5c6.jpg'

# %%
from src.procyclingstats import get_stage

# %%
get_stage("tour-de-france", 2015, 10)
# Out:
# {'race': 'tour-de-france',
#  'year': 2015,
#  'number': 10,
#  'start/finish': 'Tarbes › La Pierre-Saint-Martin',
#  'distance': 167.0,
#  'time trial': False,
#  'winner': 'christopher-froome',
#  'profile': 'images/profiles/ap/dd/tour-de-france-2015-stage-10-profile-n2-f1e22a96f4.jpg'}
